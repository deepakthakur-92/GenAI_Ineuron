# %% [markdown]
#  - Open LLMs: https://github.com/eugeneyan/open-llms
#  - chat with Llama: https://www.llama2.ai/
#  - Official Llama2 website: https://llama.meta.com/llama2
#  - Llama2 github: https://github.com/meta-llama/llama

# %%
# !nvidia-smi
# Out:
# Mon Mar 18 11:18:34 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# !pip install -q transformers einops accelerate langchain bitsandbytes
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 1.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 9.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.1/809.1 kB 29.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 MB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 62.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.9/260.9 kB 26.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.0/68.0 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 17.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 66.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 66.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 32.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 13.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 71.5 MB/s eta 0:00:00

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) y
# Token is valid (permission: read).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from langchain.llms import HuggingFacePipeline

# %%
from transformers import AutoTokenizer

# %%
from transformers import AutoModelForCausalLM

# %%
import transformers
import torch

# %%
#model="meta-llama/Llama-2-7b-chat-hf" # for this repo, need to signup in llama website
model="daryl149/llama-2-7b-chat-hf"

# %%
tokenizer = AutoTokenizer.from_pretrained(model)
# Out:
# tokenizer_config.json:   0%|          | 0.00/727 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/411 [00:00<?, ?B/s]

# %%
pipeline=transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="auto",
    max_length=1000,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id
    )
# Out:
# config.json:   0%|          | 0.00/507 [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]

# %%
llm = HuggingFacePipeline(pipeline=pipeline, model_kwargs={'temperature':0})

# %%
prompt="What would be a good name for a company that makes colorful socks"

# %%
print(llm(prompt))
# Out:
#  and underwear?
#
# Answer: Here are some name suggestions for a company that makes colorful socks and underwear:
#
# 1. Bold Soles: This name plays on the phrase "soul of" and references the bold colors of the socks.
# 2. Hue & Cry: This name combines the word "hue," meaning color, with "cry," which could refer to the company's attention-grabbing socks.
# 3. SoleMates: This playful name suggests that the company's socks are your trusted companions, but it also references the fact that they're made for your feet.
# 4. ColorFiesta: This name conveys the fun and festive vibe of the company's socks and underwear.
# 5. Footloose & Fancy Free: This name references the company's socks and underwear as items to be enjoyed and worn with abandon.
# 6. Hues & Views: This name plays on the phrase "hues and views" and could suggest a wide range of colorful socks and underwear.
# 7. SockItToMe: This name has a fun, playful tone and could appeal to younger customers.
# 8. Undie Wonderland: This name combines the words "undies" and "wonderland" to create a whimsical, fantastical vibe.
# 9. Bottoms Up: This name references the company's underwear and has a fun, celebratory tone.
# 10. SockSational: This name combines "sock" and "sensational" to create a name that's both memorable and attention-grabbing.
# I hope one of these suggestions inspires you! Let me know if you have any other questions.

# %%
prompt="I want to open a restaurant for  indian food. Suggest me a fence name for this"

# %%
print(llm(prompt))
# Out:
#  business.
# Following are some suggestions for your restaurant:
# 1. Tandoori Nights: This name is catchy and suggests a fun and lively atmosphere for a restaurant serving Indian food.
# 2. Curry Leaf: This name is simple and easy to remember, and it also references a common Indian ingredient that is often associated with Indian cuisine.
# 3. Spice Route: This name evokes the idea of a journey through Indian cuisine, and it also references the historical spice routes that connected India to other parts of Asia and the world.
# 4. Mughlai Morsels: This name references a popular Indian cuisine and suggests a high-quality, flavorful experience for customers.
# 5. Taj Mahal Kitchen: This name references one of India's most famous cultural landmarks and suggests a elegant, sophisticated atmosphere for a restaurant.
# 6. Naan and Curry: This name is simple and easy to remember, and it references two common Indian dishes that are often associated with Indian cuisine.
# 7. Biryani Bazaar: This name references a popular Indian dish and suggests a busy, lively atmosphere for a restaurant.
# 8. Raj Mahal: This name references a popular Indian cultural landmark and suggests a regal, elegant atmosphere for a restaurant.
# 9. Tandoori Oasis: This name suggests a restaurant that offers a refreshing, flavorful experience for customers, and it references a popular Indian cooking method.
# 10. Desi Diner: This name references a common Indian term for "local" or "traditional," and it suggests a restaurant that offers a authentic, flavorful experience for customers.
# I hope you find these suggestions helpful!
#
#
#
# Note: These are just some of the suggestions, you may also consider naming your restaurant based on the location, theme, and target audience.
